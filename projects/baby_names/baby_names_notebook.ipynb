# %% [markdown]
# ## 1. Classic American names
# <p><img src="https://assets.datacamp.com/production/project_1441/img/name.jpg" alt="Lots of name tags piled on top of each other." width="600"></p>
# <p>Photo by Travis Wise on <a href="https://commons.wikimedia.org/wiki/File:Hello_My_Name_Is_(15283079263).jpg">Wikimedia</a>.</p>
# <p>How have American baby name tastes changed since 1920?  Which names have remained popular for over 100 years, and how do those names compare to more recent top baby names? These are considerations for many new parents, but the skills we'll practice while answering these queries are broadly applicable. After all, understanding trends and popularity is important for many businesses, too! </p>
# <p>We'll be working with data provided by the United States Social Security Administration, which lists first names along with the number and sex of babies they were given to in each year. For processing speed purposes, we've limited the dataset to first names which were given to over 5,000 American babies in a given year. Our data spans 101 years, from 1920 through 2020.</p>
# <h3 id="baby_names"><code>baby_names</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>year</code></td>
# <td>int</td>
# <td>year</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>first_name</code></td>
# <td>varchar</td>
# <td>first name</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>sex</code></td>
# <td>varchar</td>
# <td><code>sex</code> of babies given <code>first_name</code></td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>num</code></td>
# <td>int</td>
# <td>number of babies of <code>sex</code> given <code>first_name</code> in that <code>year</code></td>
# </tr>
# </tbody>
# </table>
# <p>Let's get oriented to American baby name tastes by looking at the names that have stood the test of time!</p>

# %% [markdown]
# ### Install sql into jupyter lab
# make sure %%capture is in **the first line**

# %%
# %%capture
# %load_ext sql

# %% [markdown]
# ### Access to local host to get data
# <p> Load dataset into mysql database
# <p> Make sure to write "%%sql" in the first line of every cell you want to run SQL query
# <p> Load data into jupyter lab:
#
# - <code>database</code>://<code>username</code>:<code>password</code>@localhost:<code>portid</code>/<code>databasename</code>.
#
# <p> In this case, the username doesn't have a password

# %%
# %%sql
# mysql://root@localhost:3306/baby_names
#
# select * from usa_baby_names limit 10;
# Out:
# 10 rows affected.
# [(1920, 'Mary', 'F', 70982),
#  (1920, 'Dorothy', 'F', 36643),
#  (1920, 'Helen', 'F', 35097),
#  (1920, 'Margaret', 'F', 27994),
#  (1920, 'Ruth', 'F', 26101),
#  (1920, 'Mildred', 'F', 18059),
#  (1920, 'Virginia', 'F', 17314),
#  (1920, 'Elizabeth', 'F', 15909),
#  (1920, 'Frances', 'F', 15883),
#  (1920, 'Anna', 'F', 14581)]

# %% [markdown]
# ## Task 1:
# Find names that have been given to over 5,000 babies of either sex every year for the 101 years from 1920 through 2020;
# recall that names only show up in our dataset when at least 5,000 babies have been given that name in year.nding.

# %%
# %%sql
#
# # Select first_name and the total number of babies that have ever been given that name
# # Group by first_name and filter for those names that appear in all 101 years
# # Order the results by the total number of babies that have ever been given that name, descending
#
# select first_name, sum(num)
# from usa_baby_names
# group by first_name
# having count(year) = 101
# order by sum(num) desc;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 8 rows affected.
# [('James', Decimal('4748138')),
#  ('John', Decimal('4510721')),
#  ('William', Decimal('3614424')),
#  ('David', Decimal('3571498')),
#  ('Joseph', Decimal('2361382')),
#  ('Thomas', Decimal('2166802')),
#  ('Charles', Decimal('2112352')),
#  ('Elizabeth', Decimal('1436286'))]

# %% [markdown]
# ### Query Explanation
# - The having **count(year) = 101** ensures that the names appear in all 101 years (from 1920 to 2020).
# - The **sum(num)** column shows the total number of babies given these names across the 101 years.
#
# ### Conclusion
# - There are eight names have been consistently popular over 101 years, with each name being given to more than 5,000 babies each year from 1920 through 2020.
# - James is the most popular name with 4,748,138 occurrences.
# - Elizabeth is the least frequent among the top names, with 1,436,286 occurrences. However, Elizabeth is the only female name in the list.

# %% [markdown]
# ## 2. Timeless or trendy?
# <p>Wow, it looks like there are a lot of timeless traditionally male names! Elizabeth is holding her own for the female names, too. </p>
# <p>Now, let's broaden our understanding of the dataset by looking at all names. We'll attempt to capture the type of popularity that each name in the dataset enjoyed. Was the name classic and popular across many years or trendy, only popular for a few years? Let's find out. </p>

# %% [markdown]
# ## Task 2:
# Classify each name's popularity according to the number of years that the name appears in the dataset_name.

# %%
# %%sql
#
# # Select first_name, the sum of babies who've ever been given that name, and popularity_type.
# # Classify all names in the dataset as 'Classic,' 'Semi-classic,' 'Semi-trendy,' or 'Trendy'
# # based on whether the name appears in the dataset more than 80, 50, 20, or 0 times, respectively.
# # Alias the new classification column as popularity_type.
# # Order the results alphabetically by first_name.
#
# select first_name, sum(num),
#     Case
#         when count(year) > 80 then 'Classic'
#         when count(year) > 50 then 'Semi-Classic'
#         when count(year) > 20 then 'Semi-Trendy'
#         Else 'Trendy'
#     end as popularity_type
# from usa_baby_names
# group by first_name
# order by first_name;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 547 rows affected.
# [('Aaliyah', Decimal('15870'), 'Trendy'),
#  ('Aaron', Decimal('530592'), 'Semi-Classic'),
#  ('Abigail', Decimal('338485'), 'Semi-Trendy'),
#  ('Adam', Decimal('497293'), 'Semi-Trendy'),
#  ('Addison', Decimal('107433'), 'Trendy'),
#  ('Adrian', Decimal('147741'), 'Semi-Trendy'),
#  ('Aidan', Decimal('68566'), 'Trendy'),
#  ('Aiden', Decimal('216194'), 'Trendy'),
#  ('Alan', Decimal('162041'), 'Semi-Trendy'),
#  ('Albert', Decimal('260945'), 'Semi-Trendy'),
#  ('Alex', Decimal('158677'), 'Semi-Trendy'),
#  ('Alexa', Decimal('33522'), 'Trendy'),
#  ('Alexander', Decimal('579854'), 'Semi-Trendy'),
#  ('Alexandra', Decimal('167122'), 'Semi-Trendy'),
#  ('Alexandria', Decimal('5026'), 'Trendy'),
#  ('Alexis', Decimal('282149'), 'Semi-Trendy'),
#  ('Alfred', Decimal('16260'), 'Trendy'),
#  ('Alice', Decimal('296559'), 'Semi-Trendy'),
#  ('Alicia', Decimal('84579'), 'Trendy'),
#  ('Allen', Decimal('10256'), 'Trendy'),
#  ('Allison', Decimal('214995'), 'Semi-Trendy'),
#  ('Alyssa', Decimal('269134'), 'Semi-Trendy'),
#  ('Amanda', Decimal('699911'), 'Semi-Trendy'),
#  ('Amber', Decimal('313418'), 'Semi-Trendy'),
#  ('Amelia', Decimal('106381'), 'Trendy'),
#  ('Amy', Decimal('569542'), 'Semi-Trendy'),
#  ('Andrea', Decimal('321655'), 'Semi-Trendy'),
#  ('Andrew', Decimal('1157548'), 'Semi-Classic'),
#  ('Angel', Decimal('157667'), 'Trendy'),
#  ('Angela', Decimal('541553'), 'Semi-Trendy'),
#  ('Angelina', Decimal('11337'), 'Trendy'),
#  ('Anita', Decimal('44692'), 'Trendy'),
#  ('Ann', Decimal('336091'), 'Semi-Trendy'),
#  ('Anna', Decimal('445496'), 'Semi-Classic'),
#  ('Anne', Decimal('70228'), 'Trendy'),
#  ('Annette', Decimal('49954'), 'Trendy'),
#  ('Annie', Decimal('95837'), 'Trendy'),
#  ('Anthony', Decimal('1344352'), 'Classic'),
#  ('Antonio', Decimal('10097'), 'Trendy'),
#  ('April', Decimal('138714'), 'Trendy'),
#  ('Aria', Decimal('52145'), 'Trendy'),
#  ('Ariana', Decimal('5497'), 'Trendy'),
#  ('Arianna', Decimal('5270'), 'Trendy'),
#  ('Ariel', Decimal('5410'), 'Trendy'),
#  ('Arthur', Decimal('309705'), 'Semi-Trendy'),
#  ('Asher', Decimal('38156'), 'Trendy'),
#  ('Ashley', Decimal('798738'), 'Semi-Trendy'),
#  ('Ashton', Decimal('5436'), 'Trendy'),
#  ('Aubrey', Decimal('72220'), 'Trendy'),
#  ('Audrey', Decimal('48341'), 'Trendy'),
#  ('Aurora', Decimal('5184'), 'Trendy'),
#  ('Austin', Decimal('365295'), 'Semi-Trendy'),
#  ('Ava', Decimal('265126'), 'Trendy'),
#  ('Avery', Decimal('112293'), 'Trendy'),
#  ('Ayden', Decimal('34244'), 'Trendy'),
#  ('Bailey', Decimal('10219'), 'Trendy'),
#  ('Barbara', Decimal('1343901'), 'Semi-Classic'),
#  ('Barry', Decimal('85434'), 'Trendy'),
#  ('Beatrice', Decimal('27983'), 'Trendy'),
#  ('Bella', Decimal('5127'), 'Trendy'),
#  ('Benjamin', Decimal('627696'), 'Semi-Trendy'),
#  ('Bentley', Decimal('16844'), 'Trendy'),
#  ('Bernice', Decimal('46347'), 'Trendy'),
#  ('Beth', Decimal('55228'), 'Trendy'),
#  ('Betty', Decimal('893396'), 'Semi-Trendy'),
#  ('Beverly', Decimal('310683'), 'Semi-Trendy'),
#  ('Billy', Decimal('270759'), 'Semi-Trendy'),
#  ('Blake', Decimal('48795'), 'Trendy'),
#  ('Bobby', Decimal('203289'), 'Semi-Trendy'),
#  ('Bonnie', Decimal('193352'), 'Semi-Trendy'),
#  ('Bradley', Decimal('147275'), 'Semi-Trendy'),
#  ('Brandi', Decimal('16199'), 'Trendy'),
#  ('Brandon', Decimal('729832'), 'Semi-Trendy'),
#  ('Brandy', Decimal('48762'), 'Trendy'),
#  ('Brayden', Decimal('93754'), 'Trendy'),
#  ('Brenda', Decimal('513283'), 'Semi-Trendy'),
#  ('Brian', Decimal('1107302'), 'Semi-Classic'),
#  ('Briana', Decimal('5001'), 'Trendy'),
#  ('Brianna', Decimal('210328'), 'Semi-Trendy'),
#  ('Brittany', Decimal('326255'), 'Trendy'),
#  ('Brittney', Decimal('37878'), 'Trendy'),
#  ('Brody', Decimal('21815'), 'Trendy'),
#  ('Brooke', Decimal('110847'), 'Trendy'),
#  ('Brooklyn', Decimal('62260'), 'Trendy'),
#  ('Bruce', Decimal('266549'), 'Semi-Trendy'),
#  ('Bryan', Decimal('314250'), 'Semi-Trendy'),
#  ('Caden', Decimal('5052'), 'Trendy'),
#  ('Caitlin', Decimal('38501'), 'Trendy'),
#  ('Caleb', Decimal('259439'), 'Semi-Trendy'),
#  ('Cameron', Decimal('253711'), 'Semi-Trendy'),
#  ('Camila', Decimal('51882'), 'Trendy'),
#  ('Carl', Decimal('334800'), 'Semi-Trendy'),
#  ('Carla', Decimal('22276'), 'Trendy'),
#  ('Carlos', Decimal('118325'), 'Trendy'),
#  ('Carol', Decimal('740607'), 'Semi-Trendy'),
#  ('Carole', Decimal('21186'), 'Trendy'),
#  ('Caroline', Decimal('5021'), 'Trendy'),
#  ('Carolyn', Decimal('438382'), 'Semi-Trendy'),
#  ('Carrie', Decimal('77899'), 'Trendy'),
#  ('Carson', Decimal('25598'), 'Trendy'),
#  ('Carter', Decimal('141274'), 'Trendy'),
#  ('Cassandra', Decimal('42677'), 'Trendy'),
#  ('Catherine', Decimal('345852'), 'Semi-Trendy'),
#  ('Cathy', Decimal('119020'), 'Trendy'),
#  ('Chad', Decimal('177923'), 'Trendy'),
#  ('Charles', Decimal('2112352'), 'Classic'),
#  ('Charlotte', Decimal('141540'), 'Trendy'),
#  ('Chase', Decimal('97684'), 'Trendy'),
#  ('Chelsea', Decimal('100857'), 'Trendy'),
#  ('Cheryl', Decimal('392691'), 'Semi-Trendy'),
#  ('Chloe', Decimal('187720'), 'Semi-Trendy'),
#  ('Chris', Decimal('48878'), 'Trendy'),
#  ('Christian', Decimal('357457'), 'Semi-Trendy'),
#  ('Christina', Decimal('366859'), 'Semi-Trendy'),
#  ('Christine', Decimal('465653'), 'Semi-Trendy'),
#  ('Christopher', Decimal('2012792'), 'Semi-Classic'),
#  ('Christy', Decimal('10235'), 'Trendy'),
#  ('Cindy', Decimal('161070'), 'Trendy'),
#  ('Claire', Decimal('10225'), 'Trendy'),
#  ('Clara', Decimal('21336'), 'Trendy'),
#  ('Clarence', Decimal('77134'), 'Trendy'),
#  ('Cody', Decimal('225952'), 'Semi-Trendy'),
#  ('Cole', Decimal('72461'), 'Trendy'),
#  ('Colin', Decimal('5122'), 'Trendy'),
#  ('Colton', Decimal('58377'), 'Trendy'),
#  ('Connie', Decimal('179476'), 'Semi-Trendy'),
#  ('Connor', Decimal('203106'), 'Semi-Trendy'),
#  ('Cooper', Decimal('31011'), 'Trendy'),
#  ('Corey', Decimal('70531'), 'Trendy'),
#  ('Cory', Decimal('29454'), 'Trendy'),
#  ('Courtney', Decimal('202829'), 'Semi-Trendy'),
#  ('Craig', Decimal('190323'), 'Semi-Trendy'),
#  ('Crystal', Decimal('239999'), 'Semi-Trendy'),
#  ('Curtis', Decimal('48098'), 'Trendy'),
#  ('Cynthia', Decimal('577859'), 'Semi-Trendy'),
#  ('Dakota', Decimal('34334'), 'Trendy'),
#  ('Dale', Decimal('130919'), 'Trendy'),
#  ('Dana', Decimal('51558'), 'Trendy'),
#  ('Daniel', Decimal('1824274'), 'Classic'),
#  ('Danielle', Decimal('299683'), 'Semi-Trendy'),
#  ('Danny', Decimal('161078'), 'Trendy'),
#  ('Darlene', Decimal('89561'), 'Trendy'),
#  ('Darren', Decimal('5935'), 'Trendy'),
#  ('Darryl', Decimal('10142'), 'Trendy'),
#  ('David', Decimal('3571498'), 'Classic'),
#  ('Dawn', Decimal('225877'), 'Semi-Trendy'),
#  ('Debbie', Decimal('138846'), 'Trendy'),
#  ('Deborah', Decimal('675049'), 'Semi-Trendy'),
#  ('Debra', Decimal('508230'), 'Semi-Trendy'),
#  ('Denise', Decimal('285039'), 'Semi-Trendy'),
#  ('Dennis', Decimal('492221'), 'Semi-Trendy'),
#  ('Derek', Decimal('105026'), 'Trendy'),
#  ('Destiny', Decimal('100465'), 'Trendy'),
#  ('Devin', Decimal('70280'), 'Trendy'),
#  ('Diana', Decimal('172195'), 'Semi-Trendy'),
#  ('Diane', Decimal('453135'), 'Semi-Trendy'),
#  ('Diego', Decimal('46535'), 'Trendy'),
#  ('Dillon', Decimal('5062'), 'Trendy'),
#  ('Dolores', Decimal('101453'), 'Trendy'),
#  ('Dominic', Decimal('67420'), 'Trendy'),
#  ('Donald', Decimal('1280236'), 'Semi-Classic'),
#  ('Donna', Decimal('762594'), 'Semi-Trendy'),
#  ('Doris', Decimal('336062'), 'Semi-Trendy'),
#  ('Dorothy', Decimal('791084'), 'Semi-Trendy'),
#  ('Douglas', Decimal('426439'), 'Semi-Trendy'),
#  ('Dustin', Decimal('138651'), 'Trendy'),
#  ('Dylan', Decimal('360776'), 'Semi-Trendy'),
#  ('Earl', Decimal('74214'), 'Trendy'),
#  ('Easton', Decimal('21820'), 'Trendy'),
#  ('Edith', Decimal('53687'), 'Trendy'),
#  ('Edna', Decimal('63698'), 'Trendy'),
#  ('Edward', Decimal('1013143'), 'Semi-Classic'),
#  ('Elaine', Decimal('100359'), 'Trendy'),
#  ('Eleanor', Decimal('119863'), 'Trendy'),
#  ('Eli', Decimal('74938'), 'Trendy'),
#  ('Elias', Decimal('16965'), 'Trendy'),
#  ('Elijah', Decimal('277457'), 'Semi-Trendy'),
#  ('Elizabeth', Decimal('1436286'), 'Classic'),
#  ('Ella', Decimal('154079'), 'Trendy'),
#  ('Ellen', Decimal('82403'), 'Trendy'),
#  ('Ellie', Decimal('26266'), 'Trendy'),
#  ('Emily', Decimal('750420'), 'Semi-Trendy'),
#  ('Emma', Decimal('448087'), 'Semi-Trendy'),
#  ('Eric', Decimal('797880'), 'Semi-Classic'),
#  ('Erica', Decimal('156158'), 'Trendy'),
#  ('Erin', Decimal('239718'), 'Semi-Trendy'),
#  ('Ernest', Decimal('43959'), 'Trendy'),
#  ('Esther', Decimal('28040'), 'Trendy'),
#  ('Ethan', Decimal('408918'), 'Semi-Trendy'),
#  ('Ethel', Decimal('53359'), 'Trendy'),
#  ('Eugene', Decimal('239512'), 'Semi-Trendy'),
#  ('Evan', Decimal('203165'), 'Semi-Trendy'),
#  ('Evelyn', Decimal('310824'), 'Semi-Trendy'),
#  ('Ezekiel', Decimal('5013'), 'Trendy'),
#  ('Ezra', Decimal('24632'), 'Trendy'),
#  ('Faith', Decimal('27204'), 'Trendy'),
#  ('Florence', Decimal('99171'), 'Trendy'),
#  ('Frances', Decimal('348520'), 'Semi-Trendy'),
#  ('Francis', Decimal('59097'), 'Trendy'),
#  ('Frank', Decimal('596887'), 'Semi-Classic'),
#  ('Franklin', Decimal('5364'), 'Trendy'),
#  ('Fred', Decimal('170837'), 'Semi-Trendy'),
#  ('Gabriel', Decimal('270207'), 'Semi-Trendy'),
#  ('Gabriella', Decimal('51486'), 'Trendy'),
#  ('Gabrielle', Decimal('51144'), 'Trendy'),
#  ('Gail', Decimal('118334'), 'Trendy'),
#  ('Garrett', Decimal('15976'), 'Trendy'),
#  ('Gary', Decimal('817491'), 'Semi-Trendy'),
#  ('Gavin', Decimal('130460'), 'Trendy'),
#  ('George', Decimal('1032513'), 'Semi-Classic'),
#  ('Gerald', Decimal('327545'), 'Semi-Trendy'),
#  ('Geraldine', Decimal('52850'), 'Trendy'),
#  ('Gertrude', Decimal('16229'), 'Trendy'),
#  ('Gianna', Decimal('7826'), 'Trendy'),
#  ('Gina', Decimal('46380'), 'Trendy'),
#  ('Gladys', Decimal('77627'), 'Trendy'),
#  ('Glenn', Decimal('94437'), 'Trendy'),
#  ('Gloria', Decimal('331698'), 'Semi-Trendy'),
#  ('Grace', Decimal('254573'), 'Semi-Trendy'),
#  ('Grayson', Decimal('61689'), 'Trendy'),
#  ('Greg', Decimal('15849'), 'Trendy'),
#  ('Gregory', Decimal('644286'), 'Semi-Trendy'),
#  ('Hailey', Decimal('111571'), 'Trendy'),
#  ('Haley', Decimal('106119'), 'Trendy'),
#  ('Hannah', Decimal('392284'), 'Semi-Trendy'),
#  ('Harold', Decimal('368463'), 'Semi-Trendy'),
#  ('Harper', Decimal('86554'), 'Trendy'),
#  ('Harry', Decimal('182312'), 'Semi-Trendy'),
#  ('Hayden', Decimal('34724'), 'Trendy'),
#  ('Hazel', Decimal('66103'), 'Trendy'),
#  ('Heather', Decimal('468165'), 'Semi-Trendy'),
#  ('Helen', Decimal('569998'), 'Semi-Trendy'),
#  ('Henry', Decimal('429656'), 'Semi-Classic'),
#  ('Herbert', Decimal('52341'), 'Trendy'),
#  ('Holly', Decimal('54634'), 'Trendy'),
#  ('Howard', Decimal('157144'), 'Semi-Trendy'),
#  ('Hudson', Decimal('43048'), 'Trendy'),
#  ('Hunter', Decimal('220439'), 'Semi-Trendy'),
#  ('Ian', Decimal('159100'), 'Semi-Trendy'),
#  ('Irene', Decimal('110116'), 'Trendy'),
#  ('Isaac', Decimal('209563'), 'Semi-Trendy'),
#  ('Isabella', Decimal('336924'), 'Semi-Trendy'),
#  ('Isaiah', Decimal('200116'), 'Semi-Trendy'),
#  ('Jace', Decimal('23233'), 'Trendy'),
#  ('Jack', Decimal('552411'), 'Semi-Classic'),
#  ('Jackson', Decimal('219588'), 'Semi-Trendy'),
#  ('Jacob', Decimal('888209'), 'Semi-Trendy'),
#  ('Jacqueline', Decimal('223092'), 'Semi-Trendy'),
#  ('Jaden', Decimal('21777'), 'Trendy'),
#  ('Jaime', Decimal('13744'), 'Trendy'),
#  ('James', Decimal('4748138'), 'Classic'),
#  ('Jamie', Decimal('157417'), 'Trendy'),
#  ('Jane', Decimal('195627'), 'Semi-Trendy'),
#  ('Janet', Decimal('444842'), 'Semi-Trendy'),
#  ('Janice', Decimal('328335'), 'Semi-Trendy'),
#  ('Jared', Decimal('137848'), 'Semi-Trendy'),
#  ('Jasmine', Decimal('192464'), 'Semi-Trendy'),
#  ('Jason', Decimal('998257'), 'Semi-Trendy'),
#  ('Jaxon', Decimal('66542'), 'Trendy'),
#  ('Jaxson', Decimal('5061'), 'Trendy'),
#  ('Jay', Decimal('20682'), 'Trendy'),
#  ('Jayden', Decimal('213005'), 'Trendy'),
#  ('Jean', Decimal('363812'), 'Semi-Trendy'),
#  ('Jeff', Decimal('61390'), 'Trendy'),
#  ('Jeffery', Decimal('131241'), 'Trendy'),
#  ('Jeffrey', Decimal('907378'), 'Semi-Trendy'),
#  ('Jenna', Decimal('60548'), 'Trendy'),
#  ('Jennifer', Decimal('1404743'), 'Semi-Trendy'),
#  ('Jeremiah', Decimal('104792'), 'Trendy'),
#  ('Jeremy', Decimal('366271'), 'Semi-Trendy'),
#  ('Jerry', Decimal('494469'), 'Semi-Trendy'),
#  ('Jesse', Decimal('183645'), 'Semi-Trendy'),
#  ('Jessica', Decimal('994210'), 'Semi-Trendy'),
#  ('Jesus', Decimal('82359'), 'Trendy'),
#  ('Jill', Decimal('120405'), 'Trendy'),
#  ('Jim', Decimal('16588'), 'Trendy'),
#  ('Jimmy', Decimal('135558'), 'Semi-Trendy'),
#  ('Jo', Decimal('84238'), 'Trendy'),
#  ('Joan', Decimal('413286'), 'Semi-Trendy'),
#  ('Joanne', Decimal('77323'), 'Trendy'),
#  ('Jocelyn', Decimal('5292'), 'Trendy'),
#  ('Joe', Decimal('302127'), 'Semi-Trendy'),
#  ('John', Decimal('4510721'), 'Classic'),
#  ('Johnny', Decimal('138737'), 'Semi-Trendy'),
#  ('Jonathan', Decimal('772846'), 'Semi-Classic'),
#  ('Jordan', Decimal('426912'), 'Semi-Trendy'),
#  ('Jose', Decimal('434805'), 'Semi-Trendy'),
#  ('Joseph', Decimal('2361382'), 'Classic'),
#  ('Josephine', Decimal('69222'), 'Trendy'),
#  ('Joshua', Decimal('1204236'), 'Semi-Trendy'),
#  ('Josiah', Decimal('74001'), 'Trendy'),
#  ('Joyce', Decimal('436267'), 'Semi-Trendy'),
#  ('Juan', Decimal('189094'), 'Semi-Trendy'),
#  ('Juanita', Decimal('20758'), 'Trendy'),
#  ('Judith', Decimal('377449'), 'Semi-Trendy'),
#  ('Judy', Decimal('329356'), 'Semi-Trendy'),
#  ('Julia', Decimal('112397'), 'Trendy'),
#  ('Julian', Decimal('137742'), 'Trendy'),
#  ('Julie', Decimal('411989'), 'Semi-Trendy'),
#  ('June', Decimal('61668'), 'Trendy'),
#  ('Justin', Decimal('729931'), 'Semi-Trendy'),
#  ('Kaitlyn', Decimal('121541'), 'Trendy'),
#  ('Karen', Decimal('892033'), 'Semi-Trendy'),
#  ('Katelyn', Decimal('65023'), 'Trendy'),
#  ('Katherine', Decimal('413349'), 'Semi-Classic'),
#  ('Kathleen', Decimal('516918'), 'Semi-Trendy'),
#  ('Kathryn', Decimal('204173'), 'Semi-Trendy'),
#  ('Kathy', Decimal('269922'), 'Semi-Trendy'),
#  ('Katie', Decimal('97378'), 'Trendy'),
#  ('Kayla', Decimal('294192'), 'Semi-Trendy'),
#  ('Kaylee', Decimal('65209'), 'Trendy'),
#  ('Keith', Decimal('313978'), 'Semi-Trendy'),
#  ('Kelly', Decimal('417352'), 'Semi-Trendy'),
#  ('Kelsey', Decimal('95434'), 'Trendy'),
#  ('Kenneth', Decimal('1153846'), 'Semi-Classic'),
#  ('Kevin', Decimal('1140092'), 'Semi-Classic'),
#  ('Khloe', Decimal('5406'), 'Trendy'),
#  ('Kim', Decimal('143648'), 'Trendy'),
#  ('Kimberly', Decimal('767543'), 'Semi-Trendy'),
#  ('Kristen', Decimal('127223'), 'Trendy'),
#  ('Kristin', Decimal('81495'), 'Trendy'),
#  ('Kristina', Decimal('10585'), 'Trendy'),
#  ('Kristy', Decimal('5331'), 'Trendy'),
#  ('Krystal', Decimal('5935'), 'Trendy'),
#  ('Kyle', Decimal('394877'), 'Semi-Trendy'),
#  ('Kylie', Decimal('16309'), 'Trendy'),
#  ('Landon', Decimal('129558'), 'Trendy'),
#  ('Larry', Decimal('700521'), 'Semi-Trendy'),
#  ('Latoya', Decimal('5051'), 'Trendy'),
#  ('Laura', Decimal('587161'), 'Semi-Trendy'),
#  ('Lauren', Decimal('401513'), 'Semi-Trendy'),
#  ('Laurie', Decimal('87568'), 'Trendy'),
#  ('Lawrence', Decimal('307238'), 'Semi-Trendy'),
#  ('Layla', Decimal('74474'), 'Trendy'),
#  ('Leah', Decimal('63600'), 'Trendy'),
#  ('Leo', Decimal('32643'), 'Trendy'),
#  ('Leonard', Decimal('54127'), 'Trendy'),
#  ('Leslie', Decimal('73075'), 'Trendy'),
#  ('Levi', Decimal('91814'), 'Trendy'),
#  ('Liam', Decimal('213059'), 'Trendy'),
#  ('Lillian', Decimal('185120'), 'Semi-Trendy'),
#  ('Lily', Decimal('115354'), 'Trendy'),
#  ('Lincoln', Decimal('43147'), 'Trendy'),
#  ('Linda', Decimal('1361021'), 'Semi-Trendy'),
#  ('Lindsay', Decimal('69178'), 'Trendy'),
#  ('Lindsey', Decimal('88669'), 'Trendy'),
#  ('Lisa', Decimal('920119'), 'Semi-Trendy'),
#  ('Logan', Decimal('316927'), 'Semi-Trendy'),
#  ('Lois', Decimal('220781'), 'Semi-Trendy'),
#  ('Lori', Decimal('289439'), 'Semi-Trendy'),
#  ('Lorraine', Decimal('27338'), 'Trendy'),
#  ('Louis', Decimal('115731'), 'Trendy'),
#  ('Louise', Decimal('106456'), 'Trendy'),
#  ('Lucas', Decimal('191033'), 'Trendy'),
#  ('Lucille', Decimal('59379'), 'Trendy'),
#  ('Luis', Decimal('144176'), 'Semi-Trendy'),
#  ('Luke', Decimal('207795'), 'Semi-Trendy'),
#  ('Luna', Decimal('27822'), 'Trendy'),
#  ('Lynn', Decimal('97059'), 'Trendy'),
#  ('Mackenzie', Decimal('46972'), 'Trendy'),
#  ('Madeline', Decimal('26888'), 'Trendy'),
#  ('Madison', Decimal('378127'), 'Semi-Trendy'),
#  ('Makayla', Decimal('55446'), 'Trendy'),
#  ('Marc', Decimal('5013'), 'Trendy'),
#  ('Marcia', Decimal('15571'), 'Trendy'),
#  ('Marcus', Decimal('53788'), 'Trendy'),
#  ('Margaret', Decimal('806838'), 'Semi-Trendy'),
#  ('Maria', Decimal('417502'), 'Semi-Classic'),
#  ('Mariah', Decimal('15723'), 'Trendy'),
#  ('Marie', Decimal('249462'), 'Semi-Trendy'),
#  ('Marilyn', Decimal('286722'), 'Semi-Trendy'),
#  ('Marion', Decimal('50545'), 'Trendy'),
#  ('Marissa', Decimal('29003'), 'Trendy'),
#  ('Marjorie', Decimal('114386'), 'Trendy'),
#  ('Mark', Decimal('1265910'), 'Semi-Classic'),
#  ('Marlene', Decimal('10368'), 'Trendy'),
#  ('Marsha', Decimal('21303'), 'Trendy'),
#  ('Martha', Decimal('359762'), 'Semi-Trendy'),
#  ('Martin', Decimal('56023'), 'Trendy'),
#  ('Mary', Decimal('3215850'), 'Classic'),
#  ('Mason', Decimal('263609'), 'Semi-Trendy'),
#  ('Mateo', Decimal('45440'), 'Trendy'),
#  ('Matthew', Decimal('1567204'), 'Semi-Classic'),
#  ('Maverick', Decimal('16863'), 'Trendy'),
#  ('Maya', Decimal('5047'), 'Trendy'),
#  ('Megan', Decimal('384668'), 'Semi-Trendy'),
#  ('Melanie', Decimal('43995'), 'Trendy'),
#  ('Melissa', Decimal('666250'), 'Semi-Trendy'),
#  ('Mia', Decimal('216167'), 'Trendy'),
#  ('Michael', Decimal('4278824'), 'Classic'),
#  ('Michele', Decimal('139690'), 'Trendy'),
#  ('Michelle', Decimal('736097'), 'Semi-Trendy'),
#  ('Mike', Decimal('97902'), 'Trendy'),
#  ('Mila', Decimal('28047'), 'Trendy'),
#  ('Mildred', Decimal('195666'), 'Trendy'),
#  ('Miles', Decimal('5249'), 'Trendy'),
#  ('Miranda', Decimal('11434'), 'Trendy'),
#  ('Misty', Decimal('34935'), 'Trendy'),
#  ('Mitchell', Decimal('5370'), 'Trendy'),
#  ('Monica', Decimal('111143'), 'Trendy'),
#  ('Morgan', Decimal('157320'), 'Trendy'),
#  ('Nancy', Decimal('854761'), 'Semi-Trendy'),
#  ('Natalie', Decimal('266634'), 'Semi-Trendy'),
#  ('Nathan', Decimal('493746'), 'Semi-Trendy'),
#  ('Nathaniel', Decimal('103671'), 'Trendy'),
#  ('Nevaeh', Decimal('42926'), 'Trendy'),
#  ('Nicholas', Decimal('777269'), 'Semi-Trendy'),
#  ('Nicole', Decimal('533803'), 'Semi-Trendy'),
#  ('Noah', Decimal('389490'), 'Semi-Trendy'),
#  ('Nolan', Decimal('38147'), 'Trendy'),
#  ('Nora', Decimal('34285'), 'Trendy'),
#  ('Norma', Decimal('144522'), 'Semi-Trendy'),
#  ('Norman', Decimal('47596'), 'Trendy'),
#  ('Oliver', Decimal('107511'), 'Trendy'),
#  ('Olivia', Decimal('429118'), 'Semi-Trendy'),
#  ('Owen', Decimal('151569'), 'Trendy'),
#  ('Paige', Decimal('48894'), 'Trendy'),
#  ('Paisley', Decimal('5085'), 'Trendy'),
#  ('Pamela', Decimal('524481'), 'Semi-Trendy'),
#  ('Parker', Decimal('27453'), 'Trendy'),
#  ('Patricia', Decimal('1479802'), 'Semi-Classic'),
#  ('Patrick', Decimal('559661'), 'Semi-Classic'),
#  ('Paul', Decimal('1218996'), 'Semi-Classic'),
#  ('Paula', Decimal('196090'), 'Semi-Trendy'),
#  ('Pauline', Decimal('64073'), 'Trendy'),
#  ('Peggy', Decimal('220586'), 'Semi-Trendy'),
#  ('Penelope', Decimal('43409'), 'Trendy'),
#  ('Penny', Decimal('10128'), 'Trendy'),
#  ('Peter', Decimal('388795'), 'Semi-Classic'),
#  ('Peyton', Decimal('5315'), 'Trendy'),
#  ('Philip', Decimal('100415'), 'Trendy'),
#  ('Phillip', Decimal('86811'), 'Trendy'),
#  ('Phyllis', Decimal('251517'), 'Semi-Trendy'),
#  ('Rachel', Decimal('434626'), 'Semi-Trendy'),
#  ('Ralph', Decimal('273663'), 'Semi-Trendy'),
#  ('Randall', Decimal('89055'), 'Trendy'),
#  ('Randy', Decimal('215094'), 'Trendy'),
#  ('Raymond', Decimal('541922'), 'Semi-Classic'),
#  ('Rebecca', Decimal('638458'), 'Semi-Classic'),
#  ('Regina', Decimal('10003'), 'Trendy'),
#  ('Renee', Decimal('61185'), 'Trendy'),
#  ('Rhonda', Decimal('157706'), 'Trendy'),
#  ('Richard', Decimal('2414838'), 'Classic'),
#  ('Rick', Decimal('5462'), 'Trendy'),
#  ('Ricky', Decimal('119547'), 'Trendy'),
#  ('Riley', Decimal('73607'), 'Trendy'),
#  ('Rita', Decimal('125877'), 'Semi-Trendy'),
#  ('Robert', Decimal('4495199'), 'Classic'),
#  ('Robin', Decimal('210806'), 'Trendy'),
#  ('Rodney', Decimal('125500'), 'Trendy'),
#  ('Roger', Decimal('314531'), 'Semi-Trendy'),
#  ('Ronald', Decimal('974343'), 'Semi-Classic'),
#  ('Ronnie', Decimal('45564'), 'Trendy'),
#  ('Rose', Decimal('248527'), 'Semi-Trendy'),
#  ('Roy', Decimal('227920'), 'Semi-Trendy'),
#  ('Ruby', Decimal('93528'), 'Trendy'),
#  ('Russell', Decimal('128647'), 'Semi-Trendy'),
#  ('Ruth', Decimal('475908'), 'Semi-Trendy'),
#  ('Ryan', Decimal('926995'), 'Semi-Trendy'),
#  ('Sabrina', Decimal('11589'), 'Trendy'),
#  ('Sally', Decimal('30713'), 'Trendy'),
#  ('Samantha', Decimal('514826'), 'Semi-Trendy'),
#  ('Samuel', Decimal('539556'), 'Semi-Classic'),
#  ('Sandra', Decimal('783878'), 'Semi-Trendy'),
#  ('Santiago', Decimal('5036'), 'Trendy'),
#  ('Sara', Decimal('226696'), 'Semi-Trendy'),
#  ('Sarah', Decimal('777519'), 'Semi-Trendy'),
#  ('Savannah', Decimal('134405'), 'Semi-Trendy'),
#  ('Scarlett', Decimal('54329'), 'Trendy'),
#  ('Scott', Decimal('704468'), 'Semi-Trendy'),
#  ('Sean', Decimal('372082'), 'Semi-Trendy'),
#  ('Sebastian', Decimal('130244'), 'Trendy'),
#  ('Seth', Decimal('35423'), 'Trendy'),
#  ('Shane', Decimal('52869'), 'Trendy'),
#  ('Shannon', Decimal('231132'), 'Semi-Trendy'),
#  ('Sharon', Decimal('647989'), 'Semi-Trendy'),
#  ('Shaun', Decimal('6107'), 'Trendy'),
#  ('Shawn', Decimal('215326'), 'Semi-Trendy'),
#  ('Sheila', Decimal('154361'), 'Semi-Trendy'),
#  ('Shelby', Decimal('68474'), 'Trendy'),
#  ('Sherri', Decimal('10819'), 'Trendy'),
#  ('Sherry', Decimal('173913'), 'Semi-Trendy'),
#  ('Shirley', Decimal('615887'), 'Semi-Trendy'),
#  ('Sierra', Decimal('38980'), 'Trendy'),
#  ('Skylar', Decimal('10408'), 'Trendy'),
#  ('Sofia', Decimal('117208'), 'Trendy'),
#  ('Sophia', Decimal('318523'), 'Semi-Trendy'),
#  ('Stacey', Decimal('67483'), 'Trendy'),
#  ('Stacy', Decimal('86835'), 'Trendy'),
#  ('Stanley', Decimal('95152'), 'Trendy'),
#  ('Stella', Decimal('10217'), 'Trendy'),
#  ('Stephanie', Decimal('651976'), 'Semi-Trendy'),
#  ('Stephen', Decimal('753958'), 'Semi-Classic'),
#  ('Steve', Decimal('114750'), 'Trendy'),
#  ('Steven', Decimal('1216819'), 'Semi-Classic'),
#  ('Sue', Decimal('10450'), 'Trendy'),
#  ('Susan', Decimal('1025728'), 'Semi-Trendy'),
#  ('Suzanne', Decimal('109387'), 'Trendy'),
#  ('Sydney', Decimal('117279'), 'Trendy'),
#  ('Tammy', Decimal('296905'), 'Trendy'),
#  ('Tanya', Decimal('22407'), 'Trendy'),
#  ('Tara', Decimal('107987'), 'Trendy'),
#  ('Taylor', Decimal('323699'), 'Semi-Trendy'),
#  ('Teresa', Decimal('298059'), 'Semi-Trendy'),
#  ('Terri', Decimal('80961'), 'Trendy'),
#  ('Terry', Decimal('346213'), 'Semi-Trendy'),
#  ('Thelma', Decimal('74017'), 'Trendy'),
#  ('Theodore', Decimal('29464'), 'Trendy'),
#  ('Theresa', Decimal('225262'), 'Semi-Trendy'),
#  ('Thomas', Decimal('2166802'), 'Classic'),
#  ('Tiffany', Decimal('283969'), 'Semi-Trendy'),
#  ('Tim', Decimal('36165'), 'Trendy'),
#  ('Timothy', Decimal('1001771'), 'Semi-Classic'),
#  ('Tina', Decimal('227252'), 'Semi-Trendy'),
#  ('Todd', Decimal('207137'), 'Trendy'),
#  ('Tom', Decimal('5061'), 'Trendy'),
#  ('Tony', Decimal('96417'), 'Trendy'),
#  ('Tonya', Decimal('58234'), 'Trendy'),
#  ('Tracey', Decimal('16979'), 'Trendy'),
#  ('Tracy', Decimal('199320'), 'Trendy'),
#  ('Travis', Decimal('218731'), 'Semi-Trendy'),
#  ('Trevor', Decimal('76138'), 'Trendy'),
#  ('Trinity', Decimal('16217'), 'Trendy'),
#  ('Tristan', Decimal('27212'), 'Trendy'),
#  ('Troy', Decimal('82294'), 'Trendy'),
#  ('Tyler', Decimal('548624'), 'Semi-Trendy'),
#  ('Valerie', Decimal('70039'), 'Trendy'),
#  ('Vanessa', Decimal('119596'), 'Trendy'),
#  ('Vicki', Decimal('94504'), 'Trendy'),
#  ('Vickie', Decimal('49252'), 'Trendy'),
#  ('Victoria', Decimal('347794'), 'Semi-Trendy'),
#  ('Vincent', Decimal('23419'), 'Trendy'),
#  ('Violet', Decimal('10471'), 'Trendy'),
#  ('Virginia', Decimal('441418'), 'Semi-Trendy'),
#  ('Walter', Decimal('378194'), 'Semi-Trendy'),
#  ('Wanda', Decimal('125458'), 'Trendy'),
#  ('Warren', Decimal('13290'), 'Trendy'),
#  ('Wayne', Decimal('211347'), 'Semi-Trendy'),
#  ('Wendy', Decimal('159446'), 'Trendy'),
#  ('Whitney', Decimal('43759'), 'Trendy'),
#  ('William', Decimal('3614424'), 'Classic'),
#  ('Willie', Decimal('274564'), 'Semi-Trendy'),
#  ('Wyatt', Decimal('128168'), 'Trendy'),
#  ('Xavier', Decimal('51892'), 'Trendy'),
#  ('Zachary', Decimal('483955'), 'Semi-Trendy'),
#  ('Zoe', Decimal('78773'), 'Trendy'),
#  ('Zoey', Decimal('70140'), 'Trendy')]

# %% [markdown]
# ### Query explanation
# The query aims to classify baby names into categories based on their presence across years.
# - The **CASE WHEN** statement is used to categorize the names into four distinct popularity types.
# - The **sum(num)** column represents the total count of babies named that particular name over all the years it has appeared.
#
# ### Conclusion
# The query successfully classifies names based on their historical presence in the dataset.
# The classification provides insight into the long-term popularity trends of baby names in the United States:
#
# - Names like Aaliyah and Addison are considered "Trendy" due to their relatively recent or infrequent use.
# - Names like Abigail and Adam are considered "Semi-Trendy", reflecting temporary naming influences. Those names are in favor for a few decades but never becoming long-term staples of baby naming trends.
# - Names such as Aaron fall into the "Semi-Classic" category, indicating more consistent use over the years but not quite at the level of "Classic" names.
# - Names like James and Michael are considered "Classic", representing enduring popularity that carry a timeless quality, making them well-suited for use across generations.
#
#
# *insert chart_1*
#
# ![image.png](attachment:41cb5ce8-4a4b-40a6-b64b-22655f465095.png)

# %% [markdown]
# ## 3. Top-ranked female names since 1920
# <p>Did you find your favorite American celebrity's name on the popularity chart? Was it classic or trendy? How do you think the name Henry did? What about Jaxon?</p>
# <p>Since we didn't get many traditionally female names in our classic American names search in the first task, let's limit our search to names which were given to female babies. </p>
# <p>We can use this opportunity to practice window functions by assigning a rank to female names based on the number of babies that have ever been given that name. What are the top-ranked female names since 1920?</p>

# %% [markdown]
# ## Task 3:
# Let's take a look at the ten highest-ranked American female names in our dataset.

# %%
# %%sql
#
# -- RANK names by the sum of babies who have ever had that name (descending), aliasing as name_rank
# -- Select name_rank, first_name, and the sum of babies who have ever had that name
# -- Filter the data for results where sex equals 'F'
# -- Limit to ten results
#
# select rank() over(order by sum(num) desc) as name_rank, first_name, sum(num)
# from usa_baby_names
# where sex = 'F'
# group by first_name
# order by name_rank
# limit 10;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 10 rows affected.
# [(1, 'Mary', Decimal('3215850')),
#  (2, 'Patricia', Decimal('1479802')),
#  (3, 'Elizabeth', Decimal('1436286')),
#  (4, 'Jennifer', Decimal('1404743')),
#  (5, 'Linda', Decimal('1361021')),
#  (6, 'Barbara', Decimal('1343901')),
#  (7, 'Susan', Decimal('1025728')),
#  (8, 'Jessica', Decimal('994210')),
#  (9, 'Lisa', Decimal('920119')),
#  (10, 'Betty', Decimal('893396'))]

# %% [markdown]
# ### Query explanation
# The query ranks female names in the dataset by their total count (sum of occurrences) using the <code>rank()</code> function.
# <p></p>The names are filtered where the sex is 'F' (female), and the result is ordered by the rank of in ascending order.
# <p></p>The query limits the output to the top 10 names ranked by total occurrences.
#
# ### Conclusion
# - When names rank in the top 10, it signifies that these names have been highly favored and frequently chosen over a significant period of time.
# - Names that appear in the top 10 tend to show long-term popularity, reflecting either classic names that have remained stable across generations or names that have surged in recent years due to cultural, celebrity, or media influence.
#
# *insert chart_2*
#
# ![image.png](attachment:f95789ae-017f-41ac-b7a6-d788588c2181.png)

# %% [markdown]
# ## 4. Picking a baby name
# <p>Perhaps a friend has heard of our work analyzing baby names and would like help choosing a name for her baby, a girl. She doesn't like any of the top-ranked names we found in the previous task. </p>
# <p>She's set on a traditionally female name ending in the letter 'a' since she's heard that vowels in baby names are trendy. She's also looking for a name that has been popular in the years since 2015. </p>
# <p>Let's see what we can do to find some options for this friend!</p>

# %%
# %%sql
#
# -- Select only the first_name column
# -- Filter for results where sex is 'F', year is greater than 2015, and first_name ends in 'a'
# -- Group by first_name and order by the total number of babies given that first_name
#
# select first_name
# from usa_baby_names
# where sex = 'F' and year > 2015 and first_name like '%a'
# group by first_name
# order by sum(num) desc;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 19 rows affected.
# [('Olivia',),
#  ('Emma',),
#  ('Ava',),
#  ('Sophia',),
#  ('Isabella',),
#  ('Mia',),
#  ('Amelia',),
#  ('Ella',),
#  ('Sofia',),
#  ('Camila',),
#  ('Aria',),
#  ('Victoria',),
#  ('Layla',),
#  ('Nora',),
#  ('Mila',),
#  ('Luna',),
#  ('Stella',),
#  ('Gianna',),
#  ('Aurora',)]

# %% [markdown]
# ### Query explanation
# The **LIKE '%a'** pattern matches any string that ends with "a". This condition ensures that only names ending with the letter 'a' are returned.
#
# ### Conclusion
# The query successfully returns a list of female baby names that end with the letter 'a' and have been popular since 2015. This set of names aligns with the trend your friend is interested in: names ending in a vowel, particularly 'a', which are currently fashionable.

# %% [markdown]
# ## 5. The Olivia expansion
# <p>Based on the results in the previous task, we can see that Olivia is the most popular female name ending in 'A' since 2015. When did the name Olivia become so popular?</p>
# <p>Let's explore the rise of the name Olivia with the help of a window function.</p>

# %% [markdown]
# ## Task 5:
# Find the cumulative number of babies named Olivia over the years since the name first appeared in our datasetrecent.

# %%
# %%sql
#
# -- Select year, first_name, num of Olivias in that year, and cumulative_olivias
# -- Use window function, Sum the cumulative babies who have been named Olivia up to that year;
# -- alias as cumulative_olivias
# -- Filter so that only data for the name Olivia is returned.
# -- Order by year from the earliest year to most recent
#
# select year, first_name, num,
#         sum(num) over (order by year) as cumulative_olivias -- order by year" sum cumulatively by year
# from usa_baby_names
# where first_name = 'Olivia'
# order by year;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 30 rows affected.
# [(1991, 'Olivia', 5601, Decimal('5601')),
#  (1992, 'Olivia', 5809, Decimal('11410')),
#  (1993, 'Olivia', 6340, Decimal('17750')),
#  (1994, 'Olivia', 6434, Decimal('24184')),
#  (1995, 'Olivia', 7624, Decimal('31808')),
#  (1996, 'Olivia', 8124, Decimal('39932')),
#  (1997, 'Olivia', 9477, Decimal('49409')),
#  (1998, 'Olivia', 10610, Decimal('60019')),
#  (1999, 'Olivia', 11255, Decimal('71274')),
#  (2000, 'Olivia', 12852, Decimal('84126')),
#  (2001, 'Olivia', 13977, Decimal('98103')),
#  (2002, 'Olivia', 14630, Decimal('112733')),
#  (2003, 'Olivia', 16152, Decimal('128885')),
#  (2004, 'Olivia', 16106, Decimal('144991')),
#  (2005, 'Olivia', 15694, Decimal('160685')),
#  (2006, 'Olivia', 15501, Decimal('176186')),
#  (2007, 'Olivia', 16584, Decimal('192770')),
#  (2008, 'Olivia', 17084, Decimal('209854')),
#  (2009, 'Olivia', 17438, Decimal('227292')),
#  (2010, 'Olivia', 17029, Decimal('244321')),
#  (2011, 'Olivia', 17327, Decimal('261648')),
#  (2012, 'Olivia', 17320, Decimal('278968')),
#  (2013, 'Olivia', 18439, Decimal('297407')),
#  (2014, 'Olivia', 19823, Decimal('317230')),
#  (2015, 'Olivia', 19710, Decimal('336940')),
#  (2016, 'Olivia', 19380, Decimal('356320')),
#  (2017, 'Olivia', 18744, Decimal('375064')),
#  (2018, 'Olivia', 18011, Decimal('393075')),
#  (2019, 'Olivia', 18508, Decimal('411583')),
#  (2020, 'Olivia', 17535, Decimal('429118'))]

# %% [markdown]
# ### Query explanation
# The **window function sum() over** that calculates the cumulative sum of the num column (the number of babies named "Olivia") over the years.
# <p>It sums the values of num (number of occurrences of the name "Olivia").
# <p>The over (order by year) clause tells the database to compute this sum for each row in the result set, ordered by the year.
# <p>It will keep adding the number of occurrences of "Olivia" for each subsequent year.
# <p>For example, if there were 100 babies named Olivia in 2000, and 120 babies named Olivia in 2001, the cumulative sum for 2001 would be 100 (from 2000) + 120 (from 2001) = 220.
# <p>The result is aliased as cumulative_olivias, meaning this column in the result set will be named cumulative_olivias.
#
#
# ### Conclusion
# - The number of babies named Olivia has increased steadily over the years. In 1991, 5,601 babies were named Olivia, and by 2020, this number had risen to 17,535, demonstrating the growing popularity of the name.
# - The cumulative total and yearly counts show that Olivia is now one of the most popular modern baby names, and its sustained popularity suggests that it will likely remain a favorite in the near future.
#
# *insert chart_3*
#
# ![image.png](attachment:d77ec67c-bed9-4883-b79e-2a77bb419877.png)

# %% [markdown]
# ## 6. Many males with the same name
# <p>Wow, Olivia has had a meteoric rise! Let's take a look at traditionally male names now. We saw in the first task that there are nine traditionally male names given to at least 5,000 babies every single year in our 101-year dataset! Those names are classics, but showing up in the dataset every year doesn't necessarily mean that the timeless names were the most popular. Let's explore popular male names a little further.</p>
# <p>In the next two tasks, we will build up to listing every year along with the most popular male name in that year. This presents a common problem: how do we find the greatest X in a group? Or, in the context of this problem, how do we find the male name given to the highest number of babies in a year? </p>
# <p>In SQL, one approach is to use a subquery. We can first write a query that selects the <code>year</code> and the maximum <code>num</code> of babies given any single male name in that year. For example, in 1989, the male name given to the highest number of babies was given to 65,339 babies. We'll write this query in this task. In the next task, we can use the code from this task as a subquery to look up the <code>first_name</code> that was given to 65,339 babies in 1989… as well as the top male first name for all other years!</p>

# %% [markdown]
# ## Task 6:
# Write a query that selects the year and the maximum num of babies given any male name in that year.

# %%
# %%sql
#
# -- Select year and maximum number of babies given any one male name in that year, aliased as max_num
# -- Filter the data to include only results where sex equals 'M'
#
# select year, max(num) as max_num
# from usa_baby_names
# where sex = 'M'
# group by year;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 101 rows affected.
# [(1920, 56914),
#  (1921, 58215),
#  (1922, 57280),
#  (1923, 57469),
#  (1924, 60801),
#  (1925, 60897),
#  (1926, 61130),
#  (1927, 61671),
#  (1928, 60703),
#  (1929, 59804),
#  (1930, 62149),
#  (1931, 60518),
#  (1932, 59265),
#  (1933, 54223),
#  (1934, 55834),
#  (1935, 56522),
#  (1936, 58499),
#  (1937, 61842),
#  (1938, 62269),
#  (1939, 59653),
#  (1940, 62476),
#  (1941, 66743),
#  (1942, 77174),
#  (1943, 80274),
#  (1944, 76954),
#  (1945, 74460),
#  (1946, 87439),
#  (1947, 94764),
#  (1948, 88589),
#  (1949, 86865),
#  (1950, 86229),
#  (1951, 87261),
#  (1952, 87063),
#  (1953, 86247),
#  (1954, 88576),
#  (1955, 88372),
#  (1956, 90665),
#  (1957, 92718),
#  (1958, 90564),
#  (1959, 85224),
#  (1960, 85933),
#  (1961, 86917),
#  (1962, 85041),
#  (1963, 83778),
#  (1964, 82642),
#  (1965, 81021),
#  (1966, 79990),
#  (1967, 82440),
#  (1968, 81995),
#  (1969, 85201),
#  (1970, 85291),
#  (1971, 77599),
#  (1972, 71401),
#  (1973, 67842),
#  (1974, 67580),
#  (1975, 68451),
#  (1976, 66947),
#  (1977, 67609),
#  (1978, 67157),
#  (1979, 67742),
#  (1980, 68704),
#  (1981, 68776),
#  (1982, 68244),
#  (1983, 68010),
#  (1984, 67745),
#  (1985, 64924),
#  (1986, 64224),
#  (1987, 63654),
#  (1988, 64150),
#  (1989, 65399),
#  (1990, 65302),
#  (1991, 60793),
#  (1992, 54397),
#  (1993, 49554),
#  (1994, 44472),
#  (1995, 41399),
#  (1996, 38365),
#  (1997, 37549),
#  (1998, 36616),
#  (1999, 35367),
#  (2000, 34483),
#  (2001, 32554),
#  (2002, 30579),
#  (2003, 29643),
#  (2004, 27886),
#  (2005, 25837),
#  (2006, 24850),
#  (2007, 24292),
#  (2008, 22603),
#  (2009, 21184),
#  (2010, 22139),
#  (2011, 20378),
#  (2012, 19088),
#  (2013, 18266),
#  (2014, 19319),
#  (2015, 19650),
#  (2016, 19154),
#  (2017, 18824),
#  (2018, 19924),
#  (2019, 20555),
#  (2020, 19659)]

# %% [markdown]
# ## 7. Top male names over the years
# <p>In the previous task, we found the maximum number of babies given any one male name in each year. Incredibly, the most popular name each year varied from being given to less than 20,000 babies to being given to more than 90,000! </p>
# <p>In this task, we find out what that top male name is for each year in our dataset. </p>

# %% [markdown]
# ## Task 7:
# Using the previous task's code as a subquery,
# look up the first_name that corresponds to the maximum number of babies given a specific male name in a yea year.

# %%
# %%sql
#
# -- Select year, first_name given to the largest number of male babies, and num of babies given that name
# -- Join baby_names to the code in the last task as a subquery
# -- using whatever alias you like and joining on both columns in the subquery
# -- Order results by year descending
#
# select b.year, b.first_name, b.num
# from usa_baby_names as b
# join (
#     select year, max(num) as max_num
#     from usa_baby_names
#     where sex = 'M'
#     group by year) as sub
# on b.year = sub.year
# and sub.max_num = b.num
# order by year desc;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 101 rows affected.
# [(2020, 'Liam', 19659),
#  (2019, 'Liam', 20555),
#  (2018, 'Liam', 19924),
#  (2017, 'Liam', 18824),
#  (2016, 'Noah', 19154),
#  (2015, 'Noah', 19650),
#  (2014, 'Noah', 19319),
#  (2013, 'Noah', 18266),
#  (2012, 'Jacob', 19088),
#  (2011, 'Jacob', 20378),
#  (2010, 'Jacob', 22139),
#  (2009, 'Jacob', 21184),
#  (2008, 'Jacob', 22603),
#  (2007, 'Jacob', 24292),
#  (2006, 'Jacob', 24850),
#  (2005, 'Jacob', 25837),
#  (2004, 'Jacob', 27886),
#  (2003, 'Jacob', 29643),
#  (2002, 'Jacob', 30579),
#  (2001, 'Jacob', 32554),
#  (2000, 'Jacob', 34483),
#  (1999, 'Jacob', 35367),
#  (1998, 'Michael', 36616),
#  (1997, 'Michael', 37549),
#  (1996, 'Michael', 38365),
#  (1995, 'Michael', 41399),
#  (1994, 'Michael', 44472),
#  (1993, 'Michael', 49554),
#  (1992, 'Michael', 54397),
#  (1991, 'Michael', 60793),
#  (1990, 'Michael', 65302),
#  (1989, 'Michael', 65399),
#  (1988, 'Michael', 64150),
#  (1987, 'Michael', 63654),
#  (1986, 'Michael', 64224),
#  (1985, 'Michael', 64924),
#  (1984, 'Michael', 67745),
#  (1983, 'Michael', 68010),
#  (1982, 'Michael', 68244),
#  (1981, 'Michael', 68776),
#  (1980, 'Michael', 68704),
#  (1979, 'Michael', 67742),
#  (1978, 'Michael', 67157),
#  (1977, 'Michael', 67609),
#  (1976, 'Michael', 66947),
#  (1975, 'Michael', 68451),
#  (1974, 'Michael', 67580),
#  (1973, 'Michael', 67842),
#  (1972, 'Michael', 71401),
#  (1971, 'Michael', 77599),
#  (1970, 'Michael', 85291),
#  (1969, 'Michael', 85201),
#  (1968, 'Michael', 81995),
#  (1967, 'Michael', 82440),
#  (1966, 'Michael', 79990),
#  (1965, 'Michael', 81021),
#  (1964, 'Michael', 82642),
#  (1963, 'Michael', 83778),
#  (1962, 'Michael', 85041),
#  (1961, 'Michael', 86917),
#  (1960, 'David', 85933),
#  (1959, 'Michael', 85224),
#  (1958, 'Michael', 90564),
#  (1957, 'Michael', 92718),
#  (1956, 'Michael', 90665),
#  (1955, 'Michael', 88372),
#  (1954, 'Michael', 88576),
#  (1953, 'Robert', 86247),
#  (1952, 'James', 87063),
#  (1951, 'James', 87261),
#  (1950, 'James', 86229),
#  (1949, 'James', 86865),
#  (1948, 'James', 88589),
#  (1947, 'James', 94764),
#  (1946, 'James', 87439),
#  (1945, 'James', 74460),
#  (1944, 'James', 76954),
#  (1943, 'James', 80274),
#  (1942, 'James', 77174),
#  (1941, 'James', 66743),
#  (1940, 'James', 62476),
#  (1939, 'Robert', 59653),
#  (1938, 'Robert', 62269),
#  (1937, 'Robert', 61842),
#  (1936, 'Robert', 58499),
#  (1935, 'Robert', 56522),
#  (1934, 'Robert', 55834),
#  (1933, 'Robert', 54223),
#  (1932, 'Robert', 59265),
#  (1931, 'Robert', 60518),
#  (1930, 'Robert', 62149),
#  (1929, 'Robert', 59804),
#  (1928, 'Robert', 60703),
#  (1927, 'Robert', 61671),
#  (1926, 'Robert', 61130),
#  (1925, 'Robert', 60897),
#  (1924, 'Robert', 60801),
#  (1923, 'John', 57469),
#  (1922, 'John', 57280),
#  (1921, 'John', 58215),
#  (1920, 'John', 56914)]

# %% [markdown]
# ### Query Explanation
# Join <code>usa_baby_names</code> and the subquery from the query of the previous task.
# <p>This subquery selects the year and the maximum number of male babies in that year. The subquery generates a result that contains two columns: year and max_num. ALias as sub
#
# <p>They join on both <code>year</code> columns and num = max_num:
#
# - **b.year = sub.year**: This ensures the records from the main query and the subquery are from the same year.
# - **sub.max_num = b.num**: This matches the maximum number of babies (sub.max_num) found in the subquery with the actual number of babies (b.num) from the main table. Essentially, it ensures you're selecting the most popular male name for each year.
#
# <code>order by year desc</code>: Finally, the results are ordered by year in descending order, meaning the most recent year appears first.
#
# ### Conclusion
# - **Liam** has been the most popular male baby name from 2017 to 2020, with a consistently high number of occurrences each year. The popularity of Liam seems to have increased in recent years, peaking in 2019 with 20,555 babies given the name.
# - **Noah** dominated from 2013 to 2016, being the most popular male name for four consecutive years. Its peak occurred in 2015 with 19,650 babies named Noah.
# - **Jacob** was the leading name from 2010 to 2012, and 2010 saw the highest occurrence of 22,139 babies named Jacob during this period, making it the most popular male name in that year.
#
# *insert chart_4*
#
# ![image.png](attachment:115ee9da-e4b1-402a-b6f1-371f54010e7f.png)

# %% [markdown]
# ## 8. The most years at number one
# <p>Noah and Liam have ruled the roost in the last few years, but if we scroll down in the results, it looks like Michael and Jacob have also spent a good number of years as the top name! Which name has been number one for the largest number of years? Let's use a common table expression to find out. </p>

# %% [markdown]
# ## Task 8:
# Return a list of first names that have been the top male first name
# in any year along with a count of the number of years that name has been the top name.

# %%
# %%sql
#
# -- Select first_name and a count of years it was the top name in the last task; alias as count_top_name
# -- Use the code from the previous task as a common table expression
# -- Group by first_name and order by count_top_name descending
#
# with top_name as (
#     select b.year, b.first_name, b.num
#     from usa_baby_names as b
#     join (
#         select year, max(num) as max_num
#         from usa_baby_names
#         where sex = 'M'
#         group by year) as sub
#     on b.year = sub.year
#     and sub.max_num = b.num
#     order by year desc)
#
# select first_name, count(year) as count_top_name
# from top_name
# group by first_name
# order by count_top_name desc;
# Out:
#  * mysql://root@localhost:3306/baby_names
# 8 rows affected.
# [('Michael', 44),
#  ('Robert', 17),
#  ('Jacob', 14),
#  ('James', 13),
#  ('Liam', 4),
#  ('John', 4),
#  ('Noah', 4),
#  ('David', 1)]

# %% [markdown]
# ### Query explanation
# 1. The query starts with defining a CTE named <code>top_name</code> and using the query from previous task. This CTE collects data about the most popular male baby name for each year.
# 2. Select <code>first_name</code>, <code>count(year)</code> as <code>count_top_name</code> from <code>top_name</code>
# <p>This part of the query selects the first name and counts the number of years it was the most popular name (from the top_name CTE).
# <p>The goal of this query is to find the male names that were the most popular across multiple years and rank them by how many years they were the top name. This is useful for identifying long-standing popular names that remained at the top of baby name rankings over several years.</p>
#
#
# ### Conclusion
# - **Michael** is the most influential name, with over four decades of being the top choice for boys' names. Its sustained popularity suggests it resonates across multiple generations.
# - The more recent popularity of names like **Liam** and **Noah** reflects changing baby name trends, with newer names rising to prominence in the 2010s.
# - Classic names such as **James, John, and Robert** have had consistent appeal over the years but have been overtaken by modern names in more recent times.
#
# *insert chart_5*
#
# ![image.png](attachment:287e4a42-7f41-44a1-a78c-58ef6626a870.png)
